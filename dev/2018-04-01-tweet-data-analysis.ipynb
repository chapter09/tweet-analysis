# %%
import pandas as pd
import numpy as np
import os, sys
import csv
pd.set_option('display.max_colwidth', -1)

# %%
data = pd.read_csv('../data/parsed/dev-labeled.csv')

# %%
data.head()
# Out:
#                   tid  \
# 0  137144184007180288
# 1  147516714798678016
# 2  149410954986270720
# 3  142720791077863424
# 4  135950336207761409
#
#                                                                                                                                           tweet  \
# 0  i came to a realization that i am happiest i have been in a very long time. i got those two nigas i love ;) @rachelpazz & myboy;) #happy.
# 1  Getting REALLY excited about @ixdconf. Passport is processing, flights are scheduled, & living is booked. What to do? #Excited #Awesomesauce
# 2  1st Driving lesson in a minute #excited
# 3  Have a good night champ (: @JohnCena u were amazing as always #proud &lt;3
# 4  @topmodel_29 HOLD UP flag on the play...i feel some type of way.I've called you twice, once on your #, left 2 vm and you tweeting smh #hurt
#
#    emotion
# 0  joy
# 1  joy
# 2  joy
# 3  joy
# 4  sadness

# %% [markdown]
# ### Preprocessing

# %%
data.shape
# Out:
# (138533, 3)

# %%
set(data['emotion'])
# Out:
# {'anger', 'fear', 'joy', 'love', 'sadness', 'surprise', 'thankfulness'}

# %%
data
# Out:
#                        tid  \
# 0       137144184007180288
# 1       147516714798678016
# 2       149410954986270720
# 3       142720791077863424
# 4       135950336207761409
# 5       144414147990392832
# 6       145012926607147008
# 7       141265140308918272
# 8       141169938550366209
# 9       135136484176048131
# 10      143502444490522624
# 11      137944262745669632
# 12      148922920972988417
# 13      139005051493556224
# 14      146636108216799232
# 15      144075899250286592
# 16      138995957676257280
# 17      146280746770894849
# 18      143738939243638785
# 19      148119809081618432
# 20      147242576263655424
# 21      148902549968257024
# 22      138751729947770880
# 23      146017804569686016
# 24      135724218678657024
# 25      148946558874947584
# 26      142574823158198274
# 27      136929703234772992
# 28      141182388989476864
# 29      148983545455583232
# ...                    ...
# 138503  146631279453028352
# 138504  135088075712901120
# ...
